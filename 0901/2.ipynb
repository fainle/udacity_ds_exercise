# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import matplotlib

# 查看系统所有字体
# from matplotlib.font_manager import FontManager
# fm = FontManager()
# mat_fonts = set(f.name for f in fm.ttflist)

df = pd.read_csv('/Users/fainle/ud/data/car/new_order.csv', )
# df.head(1)
# df.shape

df = df.rename(columns={"分类id": "category", '状态':'status', '金额':'price'})

sns.countplot(data=df, x='status'); # ;好可隐藏图标内存地址

# %%
base_color = sns.color_palette()[0]
sns.countplot(data=df, x='category', color=base_color); # ;好可隐藏图标内存地址

# %%
category_index = df['category'].value_counts().index
sns.countplot(data=df, x='category', color=base_color, order=category_index);

# %%
sns.countplot(data=df, y='status'); #

# %%
status_count = df['status'].value_counts()
n_df = df.shape[0]
max_count = status_count[0]
max_prop = max_count / n_df

tick_props = np.linspace(0, max_prop, num=10, endpoint=True, retstep=False, dtype=None)
tick_names = ['{:0.2f}'.format(v) for v in tick_props]

sns.countplot(data=df, y='status', color=base_color, order=status_count.index); #
plt.xticks(tick_props * n_df, tick_names);
i = 0
for _, v in status_count.items():
    pct_string = '{:0.1f}%'.format(100 * v/n_df)
    plt.text(v + 1, i, pct_string, va='center')
    i += 1

# %%
na_counts = df.isna().sum()
sns.barplot(na_counts.index.values, na_counts, color=base_color);

# %%
plt.pie(na_counts, labels=na_counts.index, startangle=90, counterclock=False);
# plt.axis('square')

# %%
plt.pie(na_counts, labels=na_counts.index, startangle=90, counterclock=False, wedgeprops = {'width' : 0.4});

# %%
bins = np.arange(0, df['price'].max()+50, 50)
plt.hist(data=df, x='price', bins=bins);

# %%
sns.distplot(df['price'])

# %%
sns.distplot(df['price'], kde=False)

# %%
fig = plt.figure()
ax = fig.add_axes([0.125, .125, .775, .775])

bins = np.arange(0, df['price'].max()+50, 50)
ax.hist(data=df, x='price', bins=bins);

# %%
plt.figure(figsize=[10, 5])

plt.subplot(1, 2, 1)
bins = np.arange(0, df['price'].max()+50, 50)
plt.hist(data=df, x='price', bins=bins);

plt.subplot(1, 2, 2)
bins = np.arange(0, df['price'].max()+100, 100)
plt.hist(data=df, x='price', bins=bins);

# %%
fig, axes = plt.subplots(2, 2)
axes = axes.flatten() 

for i in range(4):
    plt.sca(axes[i]) 
    plt.text(0.5, 0.5, i+1)

# %%
plt.hist(data=df, x='price', bins=bins, rwidth=0.9);

# %%
bins = 10 ** np.arange(-2, 2+0.1, 0.1)
plt.hist(data=df, x='price', bins=bins);
plt.xscale('log')

# %%
np.log10(df['price'].describe())
# Out:
# count    1.770852
# mean     1.822463
# std      2.022566
# min          -inf
# 25%     -2.000000
# 50%     -2.000000
# 75%      2.204120
# max      2.531479
# Name: price, dtype: float64
