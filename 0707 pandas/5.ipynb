# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/fainle/ud/data/09/anscombes-quartet.xlsx')

# %%
df
# Out:
#        X      Y   X.1                                                Y.1  \
# 0   10.0   8.04  10.0                                               9.14
# 1    8.0   6.95   8.0                                               8.14
# 2   13.0   7.58  13.0                                               8.74
# 3    9.0   8.81   9.0                                               8.77
# 4   11.0   8.33  11.0                                               9.26
# 5   14.0   9.96  14.0                                                8.1
# 6    6.0   7.24   6.0                                               6.13
# 7    4.0   4.26   4.0                                                3.1
# 8   12.0  10.84  12.0                                               9.13
# 9    7.0   4.82   7.0                                               7.26
# 10   5.0   5.68   5.0                                               4.74
# 11   NaN    NaN   NaN                                                NaN
# ...

# %%
df['X'].describe()
# Out:
# count    11.000000
# mean      9.000000
# std       3.316625
# min       4.000000
# 25%       6.500000
# 50%       9.000000
# 75%      11.500000
# max      14.000000
# Name: X, dtype: float64

# %%
df['X.1'].describe()
# Out:
# count    11.000000
# mean      9.000000
# std       3.316625
# min       4.000000
# 25%       6.500000
# 50%       9.000000
# 75%      11.500000
# max      14.000000
# Name: X.1, dtype: float64
