# %%
import pandas as pd

item = {
    'bob': pd.Series([245, 25, 55], index=['bike', 'pants', 'wathc']),
    'alice': pd.Series([40, 110, 500, 45], index=['book', 'glasses', 'bike', 'pants'])
}

df = pd.DataFrame(item)

# %%
df
# Out:
#            bob  alice
# bike     245.0  500.0
# book       NaN   40.0
# glasses    NaN  110.0
# pants     25.0   45.0
# wathc     55.0    NaN

# %%
pd.DataFrame(item, index=['bike'], columns=['bob'])
# Out:
#       bob
# bike  245

# %%
df[['bob']]
# Out:
#            bob
# bike     245.0
# book       NaN
# glasses    NaN
# pants     25.0
# wathc     55.0

# %%
df.loc[['bike']]
# Out:
#         bob  alice
# bike  245.0  500.0

# %%
df.iloc[:, :]
# Out:
#            bob  alice
# bike     245.0  500.0
# book       NaN   40.0
# glasses    NaN  110.0
# pants     25.0   45.0
# wathc     55.0    NaN

# %%
df['shirts'] = [3, 2, 1, 1, 1]

# %%
df
# Out:
#            bob  alice  shirts
# bike     245.0  500.0       3
# book       NaN   40.0       2
# glasses    NaN  110.0       1
# pants     25.0   45.0       1
# wathc     55.0    NaN       1

# %%
df['new'] = df['shirts']

# %%
df
# Out:
#            bob  alice  shirts  new
# bike     245.0  500.0       3    3
# book       NaN   40.0       2    2
# glasses    NaN  110.0       1    1
# pants     25.0   45.0       1    1
# wathc     55.0    NaN       1    1

# %%
df.insert(2, 'shoes', [1,1,1,1,1])

# %%
df
# Out:
#            bob  alice  shoes  shirts  new
# bike     245.0  500.0      1       3    3
# book       NaN   40.0      1       2    2
# glasses    NaN  110.0      1       1    1
# pants     25.0   45.0      1       1    1
# wathc     55.0    NaN      1       1    1

# %%
df.drop('new', axis=1)
# Out:
#            bob  alice  shoes  shirts
# bike     245.0  500.0      1       3
# book       NaN   40.0      1       2
# glasses    NaN  110.0      1       1
# pants     25.0   45.0      1       1
# wathc     55.0    NaN      1       1

# %%
df
# Out:
#            bob  alice  shoes  shirts  new
# bike     245.0  500.0      1       3    3
# book       NaN   40.0      1       2    2
# glasses    NaN  110.0      1       1    1
# pants     25.0   45.0      1       1    1
# wathc     55.0    NaN      1       1    1

# %%
df.isnull()
# Out:
#            bob  alice  shoes  shirts    new
# bike     False  False  False   False  False
# book      True  False  False   False  False
# glasses   True  False  False   False  False
# pants    False  False  False   False  False
# wathc    False   True  False   False  False

# %%
df.isnull().sum()
# Out:
# bob       2
# alice     1
# shoes     0
# shirts    0
# new       0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3

# %%
df.dropna(axis=0)
# Out:
#          bob  alice  shoes  shirts  new
# bike   245.0  500.0      1       3    3
# pants   25.0   45.0      1       1    1

# %%
df.dropna(axis=1)
# Out:
#          shoes  shirts  new
# bike         1       3    3
# book         1       2    2
# glasses      1       1    1
# pants        1       1    1
# wathc        1       1    1

# %%
df.fillna(0)
# Out:
#            bob  alice  shoes  shirts  new
# bike     245.0  500.0      1       3    3
# book       0.0   40.0      1       2    2
# glasses    0.0  110.0      1       1    1
# pants     25.0   45.0      1       1    1
# wathc     55.0    0.0      1       1    1

# %%
df.fillna(method='ffill', axis=0)
# Out:
#            bob  alice  shoes  shirts  new
# bike     245.0  500.0      1       3    3
# book     245.0   40.0      1       2    2
# glasses  245.0  110.0      1       1    1
# pants     25.0   45.0      1       1    1
# wathc     55.0   45.0      1       1    1

# %%
df.fillna(method='ffill', axis=1)
# Out:
#            bob  alice  shoes  shirts  new
# bike     245.0  500.0    1.0     3.0  3.0
# book       NaN   40.0    1.0     2.0  2.0
# glasses    NaN  110.0    1.0     1.0  1.0
# pants     25.0   45.0    1.0     1.0  1.0
# wathc     55.0   55.0    1.0     1.0  1.0

# %%
df.fillna(method='backfill', axis=1)
# Out:
#            bob  alice  shoes  shirts  new
# bike     245.0  500.0    1.0     3.0  3.0
# book      40.0   40.0    1.0     2.0  2.0
# glasses  110.0  110.0    1.0     1.0  1.0
# pants     25.0   45.0    1.0     1.0  1.0
# wathc     55.0    1.0    1.0     1.0  1.0

# %%
df.fillna(df.mean())
# Out:
#                 bob   alice  shoes  shirts  new
# bike     245.000000  500.00      1       3    3
# book     108.333333   40.00      1       2    2
# glasses  108.333333  110.00      1       1    1
# pants     25.000000   45.00      1       1    1
# wathc     55.000000  173.75      1       1    1

# %%
df.fillna(df.std())
# Out:
#                 bob       alice  shoes  shirts  new
# bike     245.000000  500.000000      1       3    3
# book     119.303534   40.000000      1       2    2
# glasses  119.303534  110.000000      1       1    1
# pants     25.000000   45.000000      1       1    1
# wathc     55.000000  219.824741      1       1    1
